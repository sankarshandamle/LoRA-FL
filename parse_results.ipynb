# %%
import os
import pickle
import numpy as np
# Define the base directory
base_dir = "out"

# Dictionary to store lists of loaded pickle objects per subfolder
pickle_data = {}

# Iterate through the directory
for root, _, files in os.walk(base_dir):
    subfolder = os.path.relpath(root, base_dir)  # Get subfolder name relative to base_dir
    if subfolder == ".":  # Skip the base "out" folder itself
        continue

    pickle_data[subfolder] = []  # Initialize list for each subfolder

    for file in files:
        if file.endswith(".pkl"):
            file_path = os.path.join(root, file)
            try:
                with open(file_path, "rb") as f:
                    pickle_data[subfolder].append(pickle.load(f))
                print(f"Loaded: {file_path} into {subfolder}")
            except Exception as e:
                print(f"Failed to load {file_path}: {e}")

print("Finished loading all pickle files.")
# Out:
# Loaded: out/Krum_Adult_30_EO/run_1.pkl into Krum_Adult_30_EO
# Loaded: out/Krum_Adult_30_EO/run_3.pkl into Krum_Adult_30_EO
# Loaded: out/Krum_Adult_30_EO/run_2.pkl into Krum_Adult_30_EO
# Loaded: out/Krum_Adult_30_EO/run_0.pkl into Krum_Adult_30_EO
# Loaded: out/Tm_Adult_20_EO/run_1.pkl into Tm_Adult_20_EO
# Loaded: out/Tm_Adult_20_EO/run_3.pkl into Tm_Adult_20_EO
# Loaded: out/Tm_Adult_20_EO/run_2.pkl into Tm_Adult_20_EO
# Loaded: out/Tm_Adult_20_EO/run_0.pkl into Tm_Adult_20_EO
# Loaded: out/Krum_Adult_40_EO/run_1.pkl into Krum_Adult_40_EO
# Loaded: out/Krum_Adult_40_EO/run_3.pkl into Krum_Adult_40_EO
# Loaded: out/Krum_Adult_40_EO/run_2.pkl into Krum_Adult_40_EO
# Loaded: out/Krum_Adult_40_EO/run_0.pkl into Krum_Adult_40_EO
# Loaded: out/FedAvg_Bank_Baseline/run_1.pkl into FedAvg_Bank_Baseline
# Loaded: out/FedAvg_Bank_Baseline/run_3.pkl into FedAvg_Bank_Baseline
# Loaded: out/FedAvg_Bank_Baseline/run_2.pkl into FedAvg_Bank_Baseline
# Loaded: out/FedAvg_Bank_Baseline/run_0.pkl into FedAvg_Bank_Baseline
# Loaded: out/FedAvg_Adult_Baseline/run_1.pkl into FedAvg_Adult_Baseline
# Loaded: out/FedAvg_Adult_Baseline/run_3.pkl into FedAvg_Adult_Baseline
# Loaded: out/FedAvg_Adult_Baseline/run_2.pkl into FedAvg_Adult_Baseline
# Loaded: out/FedAvg_Adult_Baseline/run_0.pkl into FedAvg_Adult_Baseline
# Loaded: out/FedAvg_Bank_20_EO/run_1.pkl into FedAvg_Bank_20_EO
# Loaded: out/FedAvg_Bank_20_EO/run_3.pkl into FedAvg_Bank_20_EO
# Loaded: out/FedAvg_Bank_20_EO/run_2.pkl into FedAvg_Bank_20_EO
# Loaded: out/FedAvg_Bank_20_EO/run_0.pkl into FedAvg_Bank_20_EO
# Loaded: out/Krum_Bank_Baseline/run_1.pkl into Krum_Bank_Baseline
# Loaded: out/Krum_Bank_Baseline/run_3.pkl into Krum_Bank_Baseline
# Loaded: out/Krum_Bank_Baseline/run_2.pkl into Krum_Bank_Baseline
# Loaded: out/Krum_Bank_Baseline/run_0.pkl into Krum_Bank_Baseline
# Loaded: out/FedAvg_Adult_10_EO/run_1.pkl into FedAvg_Adult_10_EO
# Loaded: out/FedAvg_Adult_10_EO/run_3.pkl into FedAvg_Adult_10_EO
# Loaded: out/FedAvg_Adult_10_EO/run_2.pkl into FedAvg_Adult_10_EO
# Loaded: out/FedAvg_Adult_10_EO/run_0.pkl into FedAvg_Adult_10_EO
# Loaded: out/Krum_Bank_40_EO/run_1.pkl into Krum_Bank_40_EO
# Loaded: out/Krum_Bank_40_EO/run_3.pkl into Krum_Bank_40_EO
# Loaded: out/Krum_Bank_40_EO/run_2.pkl into Krum_Bank_40_EO
# Loaded: out/Krum_Bank_40_EO/run_0.pkl into Krum_Bank_40_EO
# Loaded: out/Krum_Bank_30_EO/run_1.pkl into Krum_Bank_30_EO
# Loaded: out/Krum_Bank_30_EO/run_3.pkl into Krum_Bank_30_EO
# Loaded: out/Krum_Bank_30_EO/run_2.pkl into Krum_Bank_30_EO
# Loaded: out/Krum_Bank_30_EO/run_0.pkl into Krum_Bank_30_EO
# Loaded: out/FedAvg_Bank_10_EO/run_1.pkl into FedAvg_Bank_10_EO
# Loaded: out/FedAvg_Bank_10_EO/run_3.pkl into FedAvg_Bank_10_EO
# Loaded: out/FedAvg_Bank_10_EO/run_2.pkl into FedAvg_Bank_10_EO
# Loaded: out/FedAvg_Bank_10_EO/run_0.pkl into FedAvg_Bank_10_EO
# Loaded: out/Tm_Adult_30_EO/run_1.pkl into Tm_Adult_30_EO
# Loaded: out/Tm_Adult_30_EO/run_3.pkl into Tm_Adult_30_EO
# Loaded: out/Tm_Adult_30_EO/run_2.pkl into Tm_Adult_30_EO
# Loaded: out/Tm_Adult_30_EO/run_0.pkl into Tm_Adult_30_EO
# Loaded: out/Tm_Adult_10_EO/run_1.pkl into Tm_Adult_10_EO
# Loaded: out/Tm_Adult_10_EO/run_3.pkl into Tm_Adult_10_EO
# Loaded: out/Tm_Adult_10_EO/run_2.pkl into Tm_Adult_10_EO
# Loaded: out/Tm_Adult_10_EO/run_0.pkl into Tm_Adult_10_EO
# Loaded: out/FedAvg_Adult_40_EO/run_1.pkl into FedAvg_Adult_40_EO
# Loaded: out/FedAvg_Adult_40_EO/run_3.pkl into FedAvg_Adult_40_EO
# Loaded: out/FedAvg_Adult_40_EO/run_2.pkl into FedAvg_Adult_40_EO
# Loaded: out/FedAvg_Adult_40_EO/run_0.pkl into FedAvg_Adult_40_EO
# Loaded: out/FedAvg_Bank_40_EO/run_1.pkl into FedAvg_Bank_40_EO
# Loaded: out/FedAvg_Bank_40_EO/run_3.pkl into FedAvg_Bank_40_EO
# Loaded: out/FedAvg_Bank_40_EO/run_2.pkl into FedAvg_Bank_40_EO
# Loaded: out/FedAvg_Bank_40_EO/run_0.pkl into FedAvg_Bank_40_EO
# Loaded: out/FedAvg_Bank_30_EO/run_1.pkl into FedAvg_Bank_30_EO
# Loaded: out/FedAvg_Bank_30_EO/run_3.pkl into FedAvg_Bank_30_EO
# Loaded: out/FedAvg_Bank_30_EO/run_2.pkl into FedAvg_Bank_30_EO
# Loaded: out/FedAvg_Bank_30_EO/run_0.pkl into FedAvg_Bank_30_EO
# Loaded: out/Krum_Bank_10_EO/run_1.pkl into Krum_Bank_10_EO
# Loaded: out/Krum_Bank_10_EO/run_3.pkl into Krum_Bank_10_EO
# Loaded: out/Krum_Bank_10_EO/run_2.pkl into Krum_Bank_10_EO
# Loaded: out/Krum_Bank_10_EO/run_0.pkl into Krum_Bank_10_EO
# Loaded: out/Krum_Adult_Baseline/run_1.pkl into Krum_Adult_Baseline
# Loaded: out/Krum_Adult_Baseline/run_3.pkl into Krum_Adult_Baseline
# Loaded: out/Krum_Adult_Baseline/run_2.pkl into Krum_Adult_Baseline
# Loaded: out/Krum_Adult_Baseline/run_0.pkl into Krum_Adult_Baseline
# Loaded: out/Krum_Bank_20_EO/run_1.pkl into Krum_Bank_20_EO
# Loaded: out/Krum_Bank_20_EO/run_3.pkl into Krum_Bank_20_EO
# Loaded: out/Krum_Bank_20_EO/run_2.pkl into Krum_Bank_20_EO
# Loaded: out/Krum_Bank_20_EO/run_0.pkl into Krum_Bank_20_EO
# Loaded: out/FedAvg_Adult_30_EO/run_1.pkl into FedAvg_Adult_30_EO
# Loaded: out/FedAvg_Adult_30_EO/run_3.pkl into FedAvg_Adult_30_EO
# Loaded: out/FedAvg_Adult_30_EO/run_2.pkl into FedAvg_Adult_30_EO
# Loaded: out/FedAvg_Adult_30_EO/run_0.pkl into FedAvg_Adult_30_EO
# Loaded: out/Krum_Adult_20_EO/run_1.pkl into Krum_Adult_20_EO
# Loaded: out/Krum_Adult_20_EO/run_3.pkl into Krum_Adult_20_EO
# Loaded: out/Krum_Adult_20_EO/run_2.pkl into Krum_Adult_20_EO
# Loaded: out/Krum_Adult_20_EO/run_0.pkl into Krum_Adult_20_EO
# Loaded: out/FedAvg_Adult_20_EO/run_1.pkl into FedAvg_Adult_20_EO
# Loaded: out/FedAvg_Adult_20_EO/run_3.pkl into FedAvg_Adult_20_EO
# Loaded: out/FedAvg_Adult_20_EO/run_2.pkl into FedAvg_Adult_20_EO
# Loaded: out/FedAvg_Adult_20_EO/run_0.pkl into FedAvg_Adult_20_EO
# Loaded: out/Krum_Adult_10_EO/run_1.pkl into Krum_Adult_10_EO
# Loaded: out/Krum_Adult_10_EO/run_3.pkl into Krum_Adult_10_EO
# Loaded: out/Krum_Adult_10_EO/run_2.pkl into Krum_Adult_10_EO
# Loaded: out/Krum_Adult_10_EO/run_0.pkl into Krum_Adult_10_EO
# Loaded: out/Tm_Adult_Baseline/run_1.pkl into Tm_Adult_Baseline
# Loaded: out/Tm_Adult_Baseline/run_3.pkl into Tm_Adult_Baseline
# Loaded: out/Tm_Adult_Baseline/run_2.pkl into Tm_Adult_Baseline
# Loaded: out/Tm_Adult_Baseline/run_0.pkl into Tm_Adult_Baseline
# Loaded: out/Tm_Adult_40_EO/run_1.pkl into Tm_Adult_40_EO
# Loaded: out/Tm_Adult_40_EO/run_3.pkl into Tm_Adult_40_EO
# Loaded: out/Tm_Adult_40_EO/run_2.pkl into Tm_Adult_40_EO
# Loaded: out/Tm_Adult_40_EO/run_0.pkl into Tm_Adult_40_EO
# Finished loading all pickle files.

# %%
experiments = [
    "FedAvg_Adult_Baseline",
    "FedAvg_Adult_10_EO",
    "FedAvg_Adult_20_EO",
    "FedAvg_Adult_30_EO",
    "FedAvg_Adult_40_EO",
    "Krum_Adult_Baseline",
    "Krum_Adult_10_EO",
    "Krum_Adult_20_EO",
    "Krum_Adult_30_EO",
    "Krum_Adult_40_EO",
    "Tm_Adult_Baseline",
    "Tm_Adult_10_EO",
    "Tm_Adult_20_EO",
    "Tm_Adult_30_EO",
    "Tm_Adult_40_EO"
]

# experiments = [
#     "FedAvg_Bank_Baseline",
#     "FedAvg_Bank_10_EO",
#     "FedAvg_Bank_20_EO",
#     "FedAvg_Bank_30_EO",
#     "FedAvg_Bank_40_EO",
#     "Krum_Bank_Baseline",
#     "Krum_Bank_10_EO",
#     "Krum_Bank_20_EO",
#     "Krum_Bank_30_EO",
#     "Krum_Bank_40_EO",
#     "Tm_Bank_Baseline",
#     "Tm_Bank_10_EO",
#     "Tm_Bank_20_EO",
#     "Tm_Bank_30_EO",
#     "Tm_Bank_40_EO"
# ]


# Dictionary to store the computed mean and std dev per experiment
stats = {}

for experiment in experiments:
    stats[experiment] = {}  # Initialize dictionary for the experiment
    
    # Extract all runs for the experiment
    runs = pickle_data[experiment]
    
    # Get the keys from the first run (assuming all runs have the same structure)
    keys = runs[0].keys()
    
    for key in keys:
        # Collect all values for the current key across runs
        values = np.array([run[key] for run in runs])

        # Compute mean and std deviation along the first axis (runs)
        stats[experiment][key] = {
            "mean": np.mean(values, axis=0),
            "std": np.std(values, axis=0)
        }

# Print results
for experiment, values in stats.items():
    print(f"Experiment: {experiment}")
    for key, metrics in values.items():
        print(f"  {key}: Mean={metrics['mean'][-1]}, Std={metrics['std'][-1]}")
    print("-" * 50)
# Out:
# Experiment: FedAvg_Adult_Baseline
#   losses: Mean=0.32515524215996267, Std=0.0033127255838654897
#   accuracies: Mean=85.00750000000001, Std=0.19498397370040832
#   eo: Mean=0.6407893557454375, Std=0.01330138354965245
#   eopp: Mean=0.6407893557454375, Std=0.01330138354965245
#   dp: Mean=0.21989999999999998, Std=0.005216799785309008
# --------------------------------------------------
# Experiment: FedAvg_Adult_10_EO
#   losses: Mean=0.3301700118929148, Std=0.0026149277218207563
#   accuracies: Mean=84.7625, Std=0.17569504830814542
#   eo: Mean=0.6629362116853352, Std=0.01843170619883806
#   eopp: Mean=0.6629362116853352, Std=0.01843170619883806
#   dp: Mean=0.2334, Std=0.007515650337795145
# --------------------------------------------------
# Experiment: FedAvg_Adult_20_EO
#   losses: Mean=0.33703691922128204, Std=0.002843916269254219
#   accuracies: Mean=84.36250000000001, Std=0.06869315832016756
#   eo: Mean=0.6666150681200298, Std=0.008371196211854086
#   eopp: Mean=0.6666150681200298, Std=0.008371196211854086
#   dp: Mean=0.23925, Std=0.004763664555780576
# --------------------------------------------------
# Experiment: FedAvg_Adult_30_EO
#   losses: Mean=0.3493466921150684, Std=0.0022965553866753337
#   accuracies: Mean=83.45249999999999, Std=0.25202926417382854
#   eo: Mean=0.6976605329536104, Std=0.009525797058605533
#   eopp: Mean=0.6976605329536104, Std=0.009525797058605533
#   dp: Mean=0.26385000000000003, Std=0.0050341334904827435
# --------------------------------------------------
# Experiment: FedAvg_Adult_40_EO
#   losses: Mean=0.37615702450275423, Std=0.006283997124754526
#   accuracies: Mean=82.00500000000001, Std=0.2057304061144075
#   eo: Mean=0.7188822228598417, Std=0.025066199008006832
#   eopp: Mean=0.7188822228598417, Std=0.025066199008006832
#   dp: Mean=0.288725, Std=0.012388982000148357
# --------------------------------------------------
# Experiment: Krum_Adult_Baseline
#   losses: Mean=0.3276665549725294, Std=0.0041510675683880715
#   accuracies: Mean=84.76, Std=0.1278671185254424
#   eo: Mean=0.6413299211993166, Std=0.015634780272047285
#   eopp: Mean=0.6413299211993166, Std=0.015634780272047285
#   dp: Mean=0.22262500000000002, Std=0.00824511218844231
# --------------------------------------------------
# Experiment: Krum_Adult_10_EO
#   losses: Mean=0.3336066700518131, Std=0.005162131512147111
#   accuracies: Mean=84.51750000000001, Std=0.22487496525846692
#   eo: Mean=0.6535582958807649, Std=0.016883651037765297
#   eopp: Mean=0.6535582958807649, Std=0.016883651037765297
#   dp: Mean=0.23110000000000003, Std=0.007108797366643675
# --------------------------------------------------
# Experiment: Krum_Adult_20_EO
#   losses: Mean=0.3376002755016088, Std=0.006168123719415114
#   accuracies: Mean=84.21, Std=0.17677669529663828
#   eo: Mean=0.6498696884258417, Std=0.02463616316480721
#   eopp: Mean=0.6498696884258417, Std=0.02463616316480721
#   dp: Mean=0.23242500000000002, Std=0.013789738032319544
# --------------------------------------------------
# Experiment: Krum_Adult_30_EO
#   losses: Mean=0.3432972487062216, Std=0.017672142606800775
#   accuracies: Mean=83.795, Std=1.0888181666375734
#   eo: Mean=0.6490762903641504, Std=0.03322064392683137
#   eopp: Mean=0.6490762903641504, Std=0.03322064392683137
#   dp: Mean=0.236325, Std=0.02767719051854794
# --------------------------------------------------
# Experiment: Krum_Adult_40_EO
#   losses: Mean=0.3873862236738205, Std=0.02347167261569716
#   accuracies: Mean=82.1775, Std=1.2013403972230376
#   eo: Mean=0.661166454031995, Std=0.03768882284588585
#   eopp: Mean=0.661166454031995, Std=0.03768882284588585
#   dp: Mean=0.25835, Std=0.01940161075787267
# --------------------------------------------------
# Experiment: Tm_Adult_Baseline
#   losses: Mean=0.3246828811864058, Std=0.003265198394518
#   accuracies: Mean=85.04821428571428, Std=0.07531820253201196
#   eo: Mean=0.10076205205817046, Std=0.011977021135868305
#   eopp: Mean=0.07255905792926821, Std=0.010684575958513975
#   dp: Mean=0.1847504544519247, Std=0.015204517690190525
# --------------------------------------------------
# Experiment: Tm_Adult_10_EO
#   losses: Mean=0.36133794387181595, Std=0.034816249546444786
#   accuracies: Mean=84.72678571428571, Std=0.2645932091466581
#   eo: Mean=0.10773176978528255, Std=0.00968974980146901
#   eopp: Mean=0.09111065311249131, Std=0.01301256051713751
#   dp: Mean=0.17043972437054442, Std=0.018528190177596895
# --------------------------------------------------
# Experiment: Tm_Adult_20_EO
#   losses: Mean=0.37099149897694583, Std=0.0328287905773584
#   accuracies: Mean=84.33035714285714, Std=0.5522536157622165
#   eo: Mean=0.19684163061774385, Std=0.03325511917802127
#   eopp: Mean=0.19513502531201699, Std=0.03497746106792622
#   dp: Mean=0.18283058658481954, Std=0.0280173684721553
# --------------------------------------------------
# Experiment: Tm_Adult_30_EO
#   losses: Mean=0.35567249705394105, Std=0.013570967553019673
#   accuracies: Mean=84.2357142857143, Std=0.33000463818632775
#   eo: Mean=0.2007201776979477, Std=0.051624570325042606
#   eopp: Mean=0.19159400348505862, Std=0.06010203155251206
#   dp: Mean=0.224060545983057, Std=0.010928854845596034
# --------------------------------------------------
# Experiment: Tm_Adult_40_EO
#   losses: Mean=0.3751735597848892, Std=0.016913319588204533
#   accuracies: Mean=82.81964285714285, Std=1.046695175691726
#   eo: Mean=0.28116763707394654, Std=0.07559277643427088
#   eopp: Mean=0.27957714303597797, Std=0.07668266277132349
#   dp: Mean=0.26988306005041396, Std=0.053332042052969424
# --------------------------------------------------
